# %% [markdown]
# # Practical Data Science - Assignment 2

# %% [markdown]
# ## Statlog (Heart) Analysis

# %% [markdown]
#  Data collected from UCI Machine Learning Library

# %% [markdown]
# ### Attribute Information:

# %% [markdown]
# 1. age
# 2. sex (1 = male; 0 = female)
# 3. chest pain type  (4 values)
#    Value 1: typical angina
#    Value 2: atypical angina
#    Value 3: non-anginal pain
#    Value 4: asymptomatic
# 4. resting blood pressure
# 5. serum cholesterol in mg/dl
# 6. fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
# 7. resting electrocardiographic results  (values 0,1,2)
#    Value 0: normal
#    Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#    Value 2: showing probable or definite left ventricular hypertrophy
# 8. maximum heart rate achieved
# 9. exercise induced angina (1 = yes; 0 = no)
# 10. oldpeak = ST depression induced by exercise relative to rest
# 11. the slope of the peak exercise ST segment
#    Value 1: upsloping
#    Value 2: flat
#    Value 3: downsloping
# 12. number of major vessels (0-3) colored by flourosopy
# 13.  thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# ### Attributes types

# %% [markdown]
# Real: 1,4,5,8,10,12 Ordered:11, Binary: 2,6,9 Nominal:7,3,13

# %% [markdown]
# ## Variable to be predicted

# %% [markdown]
# Absence (1) or presence (2) of heart disease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn')

# %%
column_names = ['age','sex','cp_type','resting_bp','serum_cholesterol',
                'fasting_bs','resting_ec','maximum_heart_rate',
                'angina','oldpeak','slope','major_vessels','thal','heart_disease']

heart_raw = pd.read_csv('heart.dat', delimiter=' ', header=None, names=column_names, index_col=False)
heart = heart_raw.copy()

# %%
heart.head()
# Out:
#     age  sex  cp_type  resting_bp  serum_cholesterol  fasting_bs  resting_ec  \
# 0  70.0  1.0      4.0       130.0              322.0         0.0         2.0
# 1  67.0  0.0      3.0       115.0              564.0         0.0         2.0
# 2  57.0  1.0      2.0       124.0              261.0         0.0         0.0
# 3  64.0  1.0      4.0       128.0              263.0         0.0         0.0
# 4  74.0  0.0      2.0       120.0              269.0         0.0         2.0
#
#    maximum_heart_rate  angina  oldpeak  slope  major_vessels  thal  \
# 0               109.0     0.0      2.4    2.0            3.0   3.0
# 1               160.0     0.0      1.6    2.0            0.0   7.0
# 2               141.0     0.0      0.3    1.0            0.0   7.0
# 3               105.0     1.0      0.2    2.0            1.0   7.0
# 4               121.0     1.0      0.2    1.0            1.0   3.0
#
#    heart_disease
# 0              2
# 1              1
# 2              2
# 3              1
# 4              1

# %% [markdown]
# ### Give Meaningful text to nominal and binary variable

# %%
age_conversion = {0:"Female",1:"Male"}
heart.sex = heart.sex.apply(lambda x:age_conversion[x])

chest_pain = {
    1: "Typical Angina Value",
    2: "Atypical Angina Value",
    3: "Non-Anginal Pain Value",
    4: "Asymptomatic"
}
heart.cp_type = heart.cp_type.astype(int).apply(lambda x:chest_pain[x])

fasting_bp_conversion = {1:"Greater than 120", 0:"Less than 120"}
heart.fasting_bs = heart.fasting_bs.apply(lambda x:fasting_bp_conversion[x])

resting_ec_conversion = {
    0: "Normal",
    1: "ST-T wave abnormality",
    2: "Probable left ventricular hypertrophy"
}
heart.resting_ec = heart.resting_ec.astype(int).apply(lambda x:resting_ec_conversion[x])

angina_conversion = {0:"No",1:"Yes"}
heart.angina = heart.angina.apply(lambda x:angina_conversion[x])

slope_conversion = {
    1: "Upsloping Value",
    2: "Flat Value",
    3: "Downsloping"
}
heart.slope = heart.slope.astype(int).apply(lambda x:slope_conversion[x])

thal_conversion = {
    3: "Normal",
    6: "Fixed Defect",
    7: "Reversable defect"
}
heart.thal = heart.thal.astype(int).apply(lambda x:thal_conversion[x])

heart_disease_conversion = {1:"No",2:"Yes"}
heart.heart_disease = heart.heart_disease.apply(lambda x:heart_disease_conversion[x])

heart.head()
# Out:
#     age     sex                 cp_type  resting_bp  serum_cholesterol  \
# 0  70.0    Male            Asymptomatic       130.0              322.0
# 1  67.0  Female  Non-Anginal Pain Value       115.0              564.0
# 2  57.0    Male   Atypical Angina Value       124.0              261.0
# 3  64.0    Male            Asymptomatic       128.0              263.0
# 4  74.0  Female   Atypical Angina Value       120.0              269.0
#
#       fasting_bs                             resting_ec  maximum_heart_rate  \
# 0  Less than 120  Probable left ventricular hypertrophy               109.0
# 1  Less than 120  Probable left ventricular hypertrophy               160.0
# 2  Less than 120                                 Normal               141.0
# 3  Less than 120                                 Normal               105.0
# 4  Less than 120  Probable left ventricular hypertrophy               121.0
#
#   angina  oldpeak            slope  major_vessels               thal  \
# 0     No      2.4       Flat Value            3.0             Normal
# 1     No      1.6       Flat Value            0.0  Reversable defect
# 2     No      0.3  Upsloping Value            0.0  Reversable defect
# 3    Yes      0.2       Flat Value            1.0  Reversable defect
# 4    Yes      0.2  Upsloping Value            1.0             Normal
#
#   heart_disease
# 0           Yes
# 1            No
# 2           Yes
# 3            No
# 4            No

# %%
heart.dtypes
# Out:
# age                   float64
# sex                    object
# cp_type                object
# resting_bp            float64
# serum_cholesterol     float64
# fasting_bs             object
# resting_ec             object
# maximum_heart_rate    float64
# angina                 object
# oldpeak               float64
# slope                  object
# major_vessels         float64
# thal                   object
# heart_disease          object
# dtype: object

# %%
#checking the NaN values in the data set
heart.isnull().any()
# Out:
# age                   False
# sex                   False
# cp_type               False
# resting_bp            False
# serum_cholesterol     False
# fasting_bs            False
# resting_ec            False
# maximum_heart_rate    False
# angina                False
# oldpeak               False
# slope                 False
# major_vessels         False
# thal                  False
# heart_disease         False
# dtype: bool

# %% [markdown]
# ## Task 2 - Data Exploration

# %% [markdown]
# ### 1.Age

# %%
def make_histogram(df, column, title):
    plt.rcParams["figure.figsize"] = (11,7)
    df[column].plot(kind='hist', edgecolor='white', color='steelblue')

    plt.title(f'Histogram of {title}', fontsize=18, y=1.01)
    plt.xlabel(title.title(), fontsize=13)
    plt.ylabel('Count', fontsize=13)
    plt.show()

make_histogram(heart, 'age', 'Age')

# %% [markdown]
# ### 2.Sex

# %%
heart.sex.unique().tolist()
# Out:
# ['Male', 'Female']

# %%
def make_pie_chart(data, column, title):
    plt.rcParams["figure.figsize"] = (8,8)
    color_brewer = ["#FB8072", "#8DD3C7","#BEBADA","#80B1D3","#FB8072","#FFFFB3",
                         "#FDB462","#B3DE69","#FCCDE5", ]

    pd.value_counts(data[column].values, sort=True, ascending=True). \
    plot(kind='pie',autopct='%1.2f%%', colors=color_brewer)
    plt.title(f'Pie Chart of {title}', fontsize=18)
    plt.xlabel('')
    plt.ylabel('')

make_pie_chart(heart, 'sex', 'Gender Type')

# %% [markdown]
# ### 3.Chest Pain Type

# %%
heart.cp_type.unique().tolist()
# Out:
# ['Asymptomatic',
#  'Non-Anginal Pain Value',
#  'Atypical Angina Value',
#  'Typical Angina Value']

# %%
make_pie_chart(heart, 'cp_type', 'Chest Pain Type')

# %% [markdown]
# ### 4.Resting Blood Pressure

# %%
make_histogram(heart, 'resting_bp', 'Resting Blood Pressure (mmHg)')

# %% [markdown]
# ### 5.Serum Cholestoral

# %%
def make_boxplot(df, column, title):
    plt.rcParams["figure.figsize"] = (10,6)
    df[column].plot(kind='box', showfliers=True, sym='k.',vert=False, widths=.36)
    plt.title(f'Box Plot of {title}', fontsize=18, y=1.01)
    plt.xlabel(title.title(), fontsize=13)
    plt.ylabel('')
    plt.show()
make_boxplot(heart, 'serum_cholesterol', 'Serum cholesterol (Mg/dl)')

# %% [markdown]
# ### 6.Fasting Blood Sugar

# %%
heart.fasting_bs.unique()
# Out:
# array(['Less than 120', 'Greater than 120'], dtype=object)

# %%
make_pie_chart(heart, 'fasting_bs', 'Fasting Blood Sugar')

# %% [markdown]
# ### 7.Resting Electrocardiographic Results

# %%
heart.resting_ec.unique()
# Out:
# array(['Probable left ventricular hypertrophy', 'Normal',
#        'ST-T wave abnormality'], dtype=object)

# %%
make_pie_chart(heart, 'resting_ec', 'Resting Electrocardio Graph')

# %% [markdown]
# ### 8.Maximum Heart-Rate Achieved

# %%
make_boxplot(heart, 'maximum_heart_rate', 'Heart Rate (BPM)')

# %% [markdown]
# ### 9.Exercise Induced Angina

# %%
heart.angina.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
make_pie_chart(heart, 'angina', 'Exercise Induced Angina')

# %% [markdown]
# ### 10.Oldpeak

# %%
plt.rcParams["figure.figsize"] = (12,7)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.25, .75)})
sns.boxplot(heart["oldpeak"], ax=ax_box)
sns.distplot(heart["oldpeak"], ax=ax_hist)
ax_box.set(title='Distribution of Old Peak')
ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# ### 11. Slope of the peak exercise ST segment

# %%
heart.slope.unique()
# Out:
# array(['Flat Value', 'Upsloping Value', 'Downsloping'], dtype=object)

# %%
make_pie_chart(heart, 'slope', 'ST Elevation (slope)')

# %% [markdown]
# ### 12. No.of Major vessels (0-3) colored by flourosopy

# %%
plt.rcParams["figure.figsize"] = (12,7)
pd.value_counts(heart['major_vessels'].values, 
                sort=True, ascending=True).plot(kind='barh', color='steelblue')
plt.title('Bar Chart of Number of major vessels (0-3) colored by flourosopy', fontsize=18)
plt.xlabel('Count', fontsize=13)
plt.ylabel('Major Vessels', fontsize=13)
plt.show()

# %% [markdown]
# ### 13.Thal

# %%
heart.thal.unique()
# Out:
# array(['Normal', 'Reversable defect', 'Fixed Defect'], dtype=object)

# %%
make_pie_chart(heart, 'thal', 'Thalassemia')

# %% [markdown]
# ### Heart Disease

# %%
make_pie_chart(heart, 'heart_disease', 'Heart Disease')

# %% [markdown]
# ## Comparision

# %%
heart.head()
# Out:
#     age     sex                 cp_type  resting_bp  serum_cholesterol  \
# 0  70.0    Male            Asymptomatic       130.0              322.0
# 1  67.0  Female  Non-Anginal Pain Value       115.0              564.0
# 2  57.0    Male   Atypical Angina Value       124.0              261.0
# 3  64.0    Male            Asymptomatic       128.0              263.0
# 4  74.0  Female   Atypical Angina Value       120.0              269.0
#
#       fasting_bs                             resting_ec  maximum_heart_rate  \
# 0  Less than 120  Probable left ventricular hypertrophy               109.0
# 1  Less than 120  Probable left ventricular hypertrophy               160.0
# 2  Less than 120                                 Normal               141.0
# 3  Less than 120                                 Normal               105.0
# 4  Less than 120  Probable left ventricular hypertrophy               121.0
#
#   angina  oldpeak            slope  major_vessels               thal  \
# 0     No      2.4       Flat Value            3.0             Normal
# 1     No      1.6       Flat Value            0.0  Reversable defect
# 2     No      0.3  Upsloping Value            0.0  Reversable defect
# 3    Yes      0.2       Flat Value            1.0  Reversable defect
# 4    Yes      0.2  Upsloping Value            1.0             Normal
#
#   heart_disease
# 0           Yes
# 1            No
# 2           Yes
# 3            No
# 4            No

# %% [markdown]
# ### Relationship between Age and Blood Pressure

# %%
sns.set(font_scale=1)
plot = sns.jointplot(x=heart["age"], y=heart["resting_bp"], kind='scatter', size=8)
plot.ax_joint.set_xlabel('Age', fontweight='bold')
plot.ax_joint.set_ylabel('Blood Pressure', fontweight='bold')

plot.fig.subplots_adjust(top=0.9)
plot.fig.suptitle('Scatter plot of Age and Resting Blood Pressure ', fontsize=18, fontweight='bold')
# Out:
# Text(0.5,0.98,'Scatter plot of Age and Resting Blood Pressure ')

# %%
plot = sns.jointplot(x=heart["age"], y=heart["serum_cholesterol"], kind='scatter', size=8)
plot.ax_joint.set_xlabel('Age', fontweight='bold')
plot.ax_joint.set_ylabel('Serum cholesterol', fontweight='bold')

plot.fig.subplots_adjust(top=0.9)
plot.fig.suptitle('Scatter plot of Age and Serum cholesterol ', fontsize=18, fontweight='bold')
# Out:
# Text(0.5,0.98,'Scatter plot of Age and Serum cholesterol ')

# %%
heart.head()
# Out:
#     age     sex                 cp_type  resting_bp  serum_cholesterol  \
# 0  70.0    Male            Asymptomatic       130.0              322.0
# 1  67.0  Female  Non-Anginal Pain Value       115.0              564.0
# 2  57.0    Male   Atypical Angina Value       124.0              261.0
# 3  64.0    Male            Asymptomatic       128.0              263.0
# 4  74.0  Female   Atypical Angina Value       120.0              269.0
#
#       fasting_bs                             resting_ec  maximum_heart_rate  \
# 0  Less than 120  Probable left ventricular hypertrophy               109.0
# 1  Less than 120  Probable left ventricular hypertrophy               160.0
# 2  Less than 120                                 Normal               141.0
# 3  Less than 120                                 Normal               105.0
# 4  Less than 120  Probable left ventricular hypertrophy               121.0
#
#   angina  oldpeak            slope  major_vessels               thal  \
# 0     No      2.4       Flat Value            3.0             Normal
# 1     No      1.6       Flat Value            0.0  Reversable defect
# 2     No      0.3  Upsloping Value            0.0  Reversable defect
# 3    Yes      0.2       Flat Value            1.0  Reversable defect
# 4    Yes      0.2  Upsloping Value            1.0             Normal
#
#   heart_disease
# 0           Yes
# 1            No
# 2           Yes
# 3            No
# 4            No

# %%
g = sns.FacetGrid(heart, col="sex", hue="heart_disease", size=6)
g.map(plt.scatter, "resting_bp", "maximum_heart_rate", alpha=1)
g.set_axis_labels('Blood Pressure', 'Heart Rate')

plt.subplots_adjust(top=.88)
g.fig.suptitle('Relationship between Heart rate and Blood Pressure by Gender', 
               fontsize=16, fontweight='bold')
plt.legend(title="Heart Disease")
plt.show()

# %%
heart.head()
plt.rcParams["figure.figsize"] = (10,10)
sns.boxplot(x='fasting_bs', y='serum_cholesterol', hue='heart_disease', 
            data=heart, palette=["#8DD3C7", "#FB8072"])
plt.title('Relationship Between Resting Blood Sugar & Cholesterol', fontsize=18, y=1.02)
plt.xlabel('Fasting Blood Sugar', fontsize=13)
plt.ylabel('Serum Cholesterol', fontsize=13)
plt.show()

# %%
sns.factorplot(data=heart, x="sex", hue="heart_disease", kind='count', size = 7)
plt.title('Relationship Between Heart Disease and Gender Type', fontsize=18, y=1.02)
plt.xlabel('', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.show()

# %%
sns.set(font_scale=1.5)
g = sns.factorplot(data=heart, x="cp_type", hue="heart_disease", col="sex", kind='count', size = 8)
g.set_xticklabels(rotation=30)
g.set_xlabels('')
plt.subplots_adjust(top=.88)
g.fig.suptitle('Relationship between Chest pain, gender and heart disease', 
               fontsize=20, fontweight='bold')
plt.show()

# %%
sns.set(font_scale=1.4)
sns.violinplot(x="resting_ec", y="oldpeak", hue="heart_disease", data=heart, split=True)
plt.title('Relationship Between Resting Electrocardio Graph & Old Peak (ST depression)', fontsize=18, y=1.02)
plt.xlabel('Electrocardio Graph', fontsize=13)
plt.ylabel('ST Elevation', fontsize=13)
# Out:
# Text(0,0.5,'ST Elevation')

# %%
sns.set(font_scale=1.5)
g = sns.factorplot(data=heart, x="major_vessels", hue="heart_disease", col="angina", kind='count', size = 8)
g.set_xticklabels(rotation=30)
g.set_xlabels('Major vessels in heart')
plt.subplots_adjust(top=.88)
g.fig.suptitle('Relationship between Angina, Major Vessels and heart disease', 
               fontsize=20, fontweight='bold')
plt.show()

# %%
g = sns.factorplot(data=heart, x="slope", hue="resting_ec", col="heart_disease", 
                   kind='count', size = 7)
g.set_xticklabels(rotation=30)

plt.subplots_adjust(top=.88)
g.fig.suptitle('Relationship Between ST Elevation (Slope) & Electrocardio Graph Type', 
               fontsize=20, fontweight='bold')

g.set_xlabels('ST Elevation (Slope)', fontsize=13)
g.set_ylabels('Count', fontsize=13)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,10)
sns.boxplot(x='thal', y='maximum_heart_rate', hue='heart_disease', 
            data=heart)
plt.title('Relationship Between Thalassemia & Heart Rate', fontsize=18, y=1.02)
plt.xlabel('Thalassemia (Blood Disorder)')
plt.ylabel('Maximum Heart Rate')
plt.show()
